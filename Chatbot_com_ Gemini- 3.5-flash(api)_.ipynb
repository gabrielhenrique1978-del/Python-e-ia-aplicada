# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielhenrique1978-del/primeiro-projeto-py/blob/main/Chatbot_com_%20Gemini-%203.5-flash(api)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 Chatbot com Gemini 3.5 Flash

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SEU_USUARIO/SEU_REPOSITORIO/blob/main/NOME_DO_NOTEBOOK.ipynb)
#
# Projeto demonstrativo de um chatbot interativo utilizando a API do Google Gemini (`gemini-3.5-flash`).

# %%
while True:
  prompt = input('Digite a sua pergunta (ou \'fim\' para encerrar): ')
  if prompt.strip().lower() == 'fim':
    break
  try:
    resposta = chat.send_message(prompt)
    print(resposta.text)
    print('\n')
  except Exception as e:
    print(f"Ocorreu um erro: {e}")

print("Chat encerrado. Obrigado por conversar!")
# Out:
# Digite a sua pergunta (ou 'fim' para encerrar):  fim
# Chat encerrado. Obrigado por conversar!

# %%
chat = client.start_chat(history=[])
print("Sessão de chat iniciada!")
# Out:
# Sessão de chat iniciada!

# %%
import os
import google.generativeai as genai
from google.colab import userdata



# Carrega a chave da API do Gemini do gerenciador de segredos do Colab
os.environ['GOOGLE_API_KEY'] = userdata.get('gemini_key')
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# Inicializa o cliente Gemini
client = genai.GenerativeModel('gemini-3.5-flash')

print("API Key e Cliente Gemini configurados com sucesso!")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# API Key e Cliente Gemini configurados com sucesso!
